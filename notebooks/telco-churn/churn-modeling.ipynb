# %%
from ds_discovery import SyntheticBuilder, Transition, Wrangle, Controller, Commons
from ds_discovery import ModelsBuilder, FeatureCatalog

# %%
ml = ModelsBuilder.from_memory()

# %%
uri = Wrangle.from_env("telco_churn").get_persist_contract().uri
ml.set_source_uri(uri=uri)
ml.pm_persist()

# %%
df_ml = ml.load_source_canonical().drop(["CustomerID"],axis =1)
df_ml.shape

# %%
headers = Commons.filter_columns(df_ml, headers='Churn', drop=True)
ml.visual.show_pca(df_ml, headers=headers, hue='Churn')

# %%
fc = FeatureCatalog.from_memory()

# %%
fc.intent_model.select_correlated(canonical=df, target='Churn')
# Out:
# /Users/lkrishna/opt/anaconda3/lib/python3.9/site-packages/ds_discovery/intent/feature_catalog_intent.py:721: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   to_drop += (importance['feature'][1:].to_list())
# /Users/lkrishna/opt/anaconda3/lib/python3.9/site-packages/ds_discovery/intent/feature_catalog_intent.py:721: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   to_drop += (importance['feature'][1:].to_list())
# ...

# %%
df_ml.head()
# Out:
#    Churn  Gender  SeniorCitizen  Partner  Dependents  Tenure  PhoneService  \
# 0  False   False          False     True       False   False          True
# 1   True   False          False    False        True   False         False
# 2  False   False          False    False       False   False          True
# 3  False   False          False    False       False   False          True
# 4   True   False          False     True       False   False          True
#
#    MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# 0          False            False           False         False
# 1           True            False            True          True
# 2          False            False           False         False
# 3          False            False           False         False
# 4          False            False           False         False
#
#    DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# ...
