# %%
# saves you having to use print as all exposed variables are printed in the cell
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
# Project Hadron
from ds_discovery import SyntheticBuilder, Transition, Wrangle, Controller, Commons

# %%
# Data Science
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ## Transition

# %%
tr = Transition.from_env("telco_churn", has_contract=False)
tr.set_source_uri('s3://lk-datasets/kaggle/WA_Fn-UseC_-Telco-Customer-Churn.csv')
tr.set_persist()
tr.set_description("Telco Churn Dataset")

# %%
df = tr.load_source_canonical()

# %%
tr.canonical_report(df, stylise=False)
# Out:
#      Attributes (21)    dType  %_Null  %_Dom  Count  Unique  \
# 0              Churn   object     0.0  0.735   7043       2
# 1           Contract   object     0.0  0.550   7043       3
# 2         Dependents   object     0.0  0.700   7043       2
# 3   DeviceProtection   object     0.0  0.439   7043       3
# 4    InternetService   object     0.0  0.440   7043       3
# 5     MonthlyCharges  float64     0.0  0.009   7043    1585
# 6      MultipleLines   object     0.0  0.481   7043       3
# 7       OnlineBackup   object     0.0  0.438   7043       3
# 8     OnlineSecurity   object     0.0  0.497   7043       3
# 9   PaperlessBilling   object     0.0  0.592   7043       2
# 10           Partner   object     0.0  0.517   7043       2
# 11     PaymentMethod   object     0.0  0.336   7043       4
# 12      PhoneService   object     0.0  0.903   7043       2
# 13     SeniorCitizen    int64     0.0  0.838   7043       2
# 14   StreamingMovies   object     0.0  0.395   7043       3
# 15       StreamingTV   object     0.0  0.399   7043       3
# 16       TechSupport   object     0.0  0.493   7043       3
# 17      TotalCharges   object     0.0  0.002   7043    6531
# 18        customerID   object     0.0  0.000   7043    7043
# 19            gender   object     0.0  0.505   7043       2
# 20            tenure    int64     0.0  0.087   7043      73
#
#                                                                                      Observations
# 0                                                                                Sample: No | Yes
# 1                                                    Sample: Month-to-month | Two year | One year
# 2                                                                                Sample: No | Yes
# 3                                                          Sample: No | Yes | No internet service
# 4                                                                  Sample: Fiber optic | DSL | No
# 5                                            max=118.75 | min=18.25 | mean=64.76 | dominant=20.05
# 6                                                             Sample: No | Yes | No phone service
# 7                                                          Sample: No | Yes | No internet service
# 8                                                          Sample: No | Yes | No internet service
# 9                                                                                Sample: Yes | No
# 10                                                                               Sample: No | Yes
# 11  Sample: Electronic check | Mailed check | Bank transfer (automatic) | Credit card (automatic)
# 12                                                                               Sample: Yes | No
# 13                                                         max=1 | min=0 | mean=0.16 | dominant=0
# 14                                                         Sample: No | Yes | No internet service
# 15                                                         Sample: No | Yes | No internet service
# 16                                                         Sample: No | Yes | No internet service
# 17                                                        Sample:   | 20.2 | 19.75 | 20.05 | 19.9
# 18                         Sample: 7590-VHVEG | 3791-LGQCY | 6008-NAIXK | 5956-YHHRX | 5365-LLFYV
# 19                                                                          Sample: Male | Female
# 20                                                       max=72 | min=0 | mean=32.37 | dominant=1

# %%
# select and type from observations
df = tr.tools.auto_clean_header(df, rename_map={'customerID': 'CustomerID', 'gender': 'Gender', 'tenure': 'Tenure'})
df = tr.tools.to_float_type(df, headers='TotalCharges')

# %%
# turn yes/no to bool to guarantee 0/1 distribution
yn = []
for col in df.columns:
    if df[col].nunique() == 2 and 'Yes' in df[col].unique().tolist():
        yn.append(col)
df = tr.tools.to_bool_type(df, headers=yn, bool_map={'Yes': True})

# %%
# run the pipeline
tr.run_component_pipeline()

# %% [markdown]
# -----------------
# ### Synthetic

# %%
builder = SyntheticBuilder.from_env("telco_churn", has_contract=False)

# %%
# set the output
builder.set_persist()
# point to the clean sample
builder.add_connector_uri('clean_sample', uri=tr.from_env("telco_churn").get_persist_contract().uri)
sample = builder.load_canonical('clean_sample')

# %%
# target
y = sample['Churn']
# features
X = sample.drop(['Churn', 'CustomerID'], axis=1)

# %%
# synthesis the sample
size = 1000
a ={}
for c in X.columns:
    a.update({c: {}})
    
# churn is the target
df = builder.tools.model_analysis(size, other='clean_sample', columns_list=[{'Churn':{}},a], column_name='analysis')
df.shape
# Out:
# (1000, 20)

# %%
# rebuild the customer_id as a unique reference
df['CustomerID'] = builder.tools.get_number(from_value=1000000, to_value=9999999, at_most=1, size=size, column_name='CustomerID')

# %%
# run the pipeline with 10,000 rows
builder.run_component_pipeline(canonical=10000)

# %% [markdown]
# ## Feature engineering

# %%
wr = Wrangle.from_env("telco_churn", has_contract=False)

# %%
wr.set_source_uri(uri=builder.from_env("telco_churn").get_persist_contract().uri)
wr.set_persist()

# %%
df = wr.load_source_canonical()

# %%
# predictors
X = df.drop(['Churn', 'CustomerID'], axis=1)
# target
y = df['Churn']

# %%
y.head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# Name: Churn, dtype: bool

# %%
# convert all categoricals to one-hot from k-1
# Warning: increase of dimentionality
cats = Commons.filter_headers(X, dtype='object')
df = wr.tools.model_encode_one_hot(df, headers=cats, drop_first=True, column_name='one_hot_k-1')

# %%
df.head()
# Out:
#    CustomerID  Churn  Gender  SeniorCitizen  Partner  Dependents  Tenure  \
# 0     1615599  False   False          False     True       False   False
# 1     9308799  False   False          False     True       False   False
# 2     2783349  False   False          False    False        True   False
# 3     7512399  False   False          False    False        True   False
# 4     5753349   True   False          False     True       False   False
#
#    PhoneService  MultipleLines  InternetService  ...  OnlineBackup  \
# 0          True          False            False  ...         False
# 1          True          False            False  ...         False
# 2         False           True            False  ...          True
# 3          True           True            False  ...          True
# 4          True          False            False  ...         False
#
#    DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# 0             False        False        False            False     False
# 1             False        False        False            False     False
# 2              True         True         True             True     False
# 3              True         True         True             True     False
# 4             False        False        False            False     False
#
#    PaperlessBilling  PaymentMethod  MonthlyCharges  TotalCharges
# 0              True          False           False         False
# 1              True          False           False         False
# 2             False          False           False         False
# 3             False          False           False         False
# 4              True          False           False         False
#
# [5 rows x 21 columns]

# %%
# normalise all floats
for c in Commons.filter_headers(X, dtype='float'):
    df[c] = wr.tools.correlate_numbers(df, header=c, normalize=(-1.,1.), column_name=f'{c}_norm')

# %%
wr.canonical_report(df, stylise=False)
# Out:
#      Attributes (21)  dType  %_Null  %_Dom  Count  Unique  \
# 0              Churn   bool     0.0  0.732  10000       2
# 1           Contract   bool     0.0  1.000  10000       1
# 2         CustomerID  int64     0.0  0.000  10000   10000
# 3         Dependents   bool     0.0  0.700  10000       2
# 4   DeviceProtection   bool     0.0  0.656  10000       2
# 5             Gender   bool     0.0  1.000  10000       1
# 6    InternetService   bool     0.0  1.000  10000       1
# 7     MonthlyCharges   bool     0.0  1.000  10000       1
# 8      MultipleLines   bool     0.0  0.582  10000       2
# 9       OnlineBackup   bool     0.0  0.655  10000       2
# 10    OnlineSecurity   bool     0.0  0.713  10000       2
# 11  PaperlessBilling   bool     0.0  0.592  10000       2
# 12           Partner   bool     0.0  0.512  10000       2
# 13     PaymentMethod   bool     0.0  1.000  10000       1
# 14      PhoneService   bool     0.0  0.899  10000       2
# 15     SeniorCitizen   bool     0.0  1.000  10000       1
# 16   StreamingMovies   bool     0.0  0.615  10000       2
# 17       StreamingTV   bool     0.0  0.619  10000       2
# 18       TechSupport   bool     0.0  0.709  10000       2
# 19            Tenure   bool     0.0  1.000  10000       1
# 20      TotalCharges   bool     0.0  1.000  10000       1
#
#                                                                  Observations
# 0                                                                False | True
# 1                                                                       False
# 2   max=9999549 | min=1000449 | mean=5480465.67 | dominant=[1000449, 1000899]
# 3                                                                False | True
# 4                                                                False | True
# 5                                                                       False
# 6                                                                       False
# 7                                                                       False
# 8                                                                False | True
# 9                                                                False | True
# 10                                                               False | True
# 11                                                               True | False
# 12                                                               True | False
# 13                                                                      False
# 14                                                               True | False
# 15                                                                      False
# 16                                                               False | True
# 17                                                               False | True
# 18                                                               False | True
# 19                                                                      False
# 20                                                                      False

# %% [markdown]
# ## Controller

# %%
controller = Controller.from_env(has_contract=False)

# %%
# register the components
controller.intent_model.transition(canonical=0, task_name="telco_churn", intent_level='telco_churn_tr')
controller.intent_model.synthetic_builder(canonical=0, task_name="telco_churn", intent_level='telco_churn_sb')
controller.intent_model.wrangle(canonical=0, task_name="telco_churn", intent_level='telco_churn_wr')

# %%
controller.report_tasks()
# Out:
# <style type="text/css">
# #T_31e84 th {
#   font-size: 120%;
#   text-align: center;
# }
# #T_31e84 .row_heading {
#   display: none;;
# }
# #T_31e84  .blank {
#   display: none;;
# }
# #T_31e84_row0_col0, #T_31e84_row1_col0, #T_31e84_row2_col0 {
#   text-align: left;
#   font-weight: bold;
#   font-size: 120%;
# }
# #T_31e84_row0_col1, #T_31e84_row0_col2, #T_31e84_row0_col3, #T_31e84_row0_col4, #T_31e84_row0_col5, #T_31e84_row1_col1, #T_31e84_row1_col2, #T_31e84_row1_col3, #T_31e84_row1_col4, #T_31e84_row1_col5, #T_31e84_row2_col1, #T_31e84_row2_col2, #T_31e84_row2_col3, #T_31e84_row2_col4, #T_31e84_row2_col5 {
#   text-align: left;
# }
# </style>
# <table id="T_31e84">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_31e84_level0_col0" class="col_heading level0 col0" >level</th>
#       <th id="T_31e84_level0_col1" class="col_heading level0 col1" >order</th>
#       <th id="T_31e84_level0_col2" class="col_heading level0 col2" >component</th>
#       <th id="T_31e84_level0_col3" class="col_heading level0 col3" >task</th>
#       <th id="T_31e84_level0_col4" class="col_heading level0 col4" >parameters</th>
#       <th id="T_31e84_level0_col5" class="col_heading level0 col5" >creator</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_31e84_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_31e84_row0_col0" class="data row0 col0" >telco_churn_sb</td>
#       <td id="T_31e84_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_31e84_row0_col2" class="data row0 col2" >SyntheticBuilder</td>
#       <td id="T_31e84_row0_col3" class="data row0 col3" >'telco_churn'</td>
#       <td id="T_31e84_row0_col4" class="data row0 col4" >[]</td>
#       <td id="T_31e84_row0_col5" class="data row0 col5" >lkrishna</td>
#     </tr>
#     <tr>
#       <th id="T_31e84_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_31e84_row1_col0" class="data row1 col0" >telco_churn_tr</td>
#       <td id="T_31e84_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_31e84_row1_col2" class="data row1 col2" >Transition</td>
#       <td id="T_31e84_row1_col3" class="data row1 col3" >'telco_churn'</td>
#       <td id="T_31e84_row1_col4" class="data row1 col4" >[]</td>
#       <td id="T_31e84_row1_col5" class="data row1 col5" >lkrishna</td>
#     </tr>
#     <tr>
#       <th id="T_31e84_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_31e84_row2_col0" class="data row2 col0" >telco_churn_wr</td>
#       <td id="T_31e84_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_31e84_row2_col2" class="data row2 col2" >Wrangle</td>
#       <td id="T_31e84_row2_col3" class="data row2 col3" >'telco_churn'</td>
#       <td id="T_31e84_row2_col4" class="data row2 col4" >[]</td>
#       <td id="T_31e84_row2_col5" class="data row2 col5" >lkrishna</td>
#     </tr>
#   </tbody>
# </table>

# %%
# run the controller and load the run report
controller.run_controller(run_cycle_report='cycle_report.csv')
controller.load_canonical(connector_name='run_cycle_report')
# Out:
#                          time                           text
# 0  2022-12-14 15:18:37.133788              start run-cycle 0
# 1  2022-12-14 15:18:37.134279             start task cycle 0
# 2  2022-12-14 15:18:37.135034         running telco_churn_tr
# 3  2022-12-14 15:18:39.129411  canonical shape is (7043, 21)
# 4  2022-12-14 15:18:39.130494         running telco_churn_sb
# 5  2022-12-14 15:18:39.181718  canonical shape is (1000, 21)
# 6  2022-12-14 15:18:39.182548         running telco_churn_wr
# 7  2022-12-14 15:18:39.188143  canonical shape is (1000, 21)
# 8  2022-12-14 15:18:39.188711                 tasks complete
# 9  2022-12-14 15:18:39.189168                  end of report

# %%
Wrangle.from_env("telco_churn").get_persist_contract().uri
# Out:
# './hadron/data/hadron_wrangle_telco_churn_primary_persist.pickle'
